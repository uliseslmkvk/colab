# %%
#Importar los módulos a utilizar
import psycopg2
import pandas as pd
import numpy as np
from datetime import datetime
pd.set_option('display.max_columns', None)
# Configura los parámetros de conexión a tu base de datos de Redshift
host = 'redshift-public.prd.de.kavak.io'
dbname = 'prod'
user = 'ulises_luna'
password = 'ZqDZ8yz49OT5UNPDu'
port = 5439  # Por defecto, el puerto de Redshift es 5439

# %%
#Importar las librerias y módulos de google

from google.colab import auth
from google.auth import default

from google.colab import files
from gspread_dataframe import set_with_dataframe

import gspread


#Autenticación en Google
auth.authenticate_user()
creds, _ =default()

gc=gspread.authorize(creds)

# %%
nombre_hoja = 'Performance MX | Costos Cash Flow'
nombre_sheet = 'SCORECARD'
hoja = gc.open(nombre_hoja).worksheet(nombre_sheet)

# Obtén todos los valores de la hoja
datos = hoja.get_all_values()
frame1=pd.DataFrame(datos)

# %%
frame1
# Out:
#                    0            1                       2        3        4  \
# 0                                                          19.5877  19.5877
# 1                                                                1        1
# 2                                  UE Autoparts Cash Flow
# 3                                                     MTD
# 4                                                   Total      FTP       RW
# 5                              Mx                     250      151       23
# 6   Ciudad de México         CDMX                     234      139       21
# 7                GDL  Guadalajara                     330      206       43
# 8                PUE       Puebla                     289      156       10
# 9                MTY    Monterrey                     205      128       17
# 10               QRO    Querétaro                     288      201       27
#
#           5           6
# 0   19.5877  2025-01-31
# 1         1  2025-01-01
# 2
# 3
# ...

# %%
# monitoreo de tiempos Daily
sheets1=gc.open("Borrador").worksheet('Cashflow')
sheets1.clear()
set_with_dataframe(sheets1,frame1)
